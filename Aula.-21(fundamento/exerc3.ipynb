# %% [markdown]
# # Relatório Preliminar de Dados

# %% [markdown]
# ## Metodologia de Limpeza

# %% [markdown]
# - Dados nulos removidos
# - Strings convertidas para minúsculas

# %% [markdown]
# **Conclusão Parcial**: processo realizado com *sucesso*.
